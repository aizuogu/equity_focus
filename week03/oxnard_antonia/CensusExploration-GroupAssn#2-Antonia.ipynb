# %%
#general data wrangling tasks
import pandas as pd

# %%
#read and visualize spatial data
import geopandas as gpd

# %%
#providing basemaps
import contextily as ctx

# %%
#give power to plots
import matplotlib.pyplot as plt

# %%
#loading geojson file
gdf=gpd.read_file('acs2019_5yr_B03002_14000US06111003609.geojson')

# %%
#shape of data
gdf.shape
# Out:
# (43, 45)

# %%
#what first five rows of data looks like
gdf.head()
# Out:
#                 geoid                             name  B03002001  \
# 0  14000US06111002500     Census Tract 25, Ventura, CA     5374.0
# 1  14000US06111002901  Census Tract 29.01, Ventura, CA     5665.0
# 2  14000US06111002905  Census Tract 29.05, Ventura, CA     5433.0
# 3  14000US06111003010  Census Tract 30.10, Ventura, CA     3226.0
# 4  14000US06111003011  Census Tract 30.11, Ventura, CA     5539.0
#
#    B03002001, Error  B03002002  B03002002, Error  B03002003  B03002003, Error  \
# 0             442.0     4419.0             433.0     4014.0             455.0
# 1             354.0     2747.0             256.0     1538.0             266.0
# 2             387.0     2339.0             313.0     1110.0             225.0
# 3             262.0      805.0             167.0      445.0              95.0
# 4             352.0     1004.0             227.0      612.0             194.0
#
#    B03002004  B03002004, Error  B03002005  B03002005, Error  B03002006  \
# ...

# %%
#plot data
gdf.plot(figsize=(12,12))
# Out:
# <AxesSubplot:>

# %%
#See all the data columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#show data
gdf.sample()
# Out:
#                  geoid                             name  B03002001  \
# 10  14000US06111003605  Census Tract 36.05, Ventura, CA     9631.0
#
#     B03002001, Error  B03002002  B03002002, Error  B03002003  \
# 10             690.0     4653.0             443.0     2765.0
#
#     B03002003, Error  B03002004  B03002004, Error  B03002005  \
# 10             598.0      445.0             250.0        0.0
#
#     B03002005, Error  B03002006  B03002006, Error  B03002007  \
# 10              17.0      891.0             361.0       31.0
#
#     B03002007, Error  B03002008  B03002008, Error  B03002009  \
# 10              33.0       60.0              93.0      461.0
#
#     B03002009, Error  B03002010  B03002010, Error  B03002011  \
# 10             205.0        0.0              17.0      461.0
#
#     B03002011, Error  B03002012  B03002012, Error  B03002013  \
# 10             205.0     4978.0             688.0     4263.0
#
#     B03002013, Error  B03002014  B03002014, Error  B03002015  \
# ...

# %%
#list columns
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B03002001',
#  'B03002001, Error',
#  'B03002002',
#  'B03002002, Error',
#  'B03002003',
#  'B03002003, Error',
#  'B03002004',
#  'B03002004, Error',
#  'B03002005',
#  'B03002005, Error',
#  'B03002006',
#  'B03002006, Error',
#  'B03002007',
#  'B03002007, Error',
#  'B03002008',
#  'B03002008, Error',
#  'B03002009',
#  'B03002009, Error',
#  'B03002010',
#  'B03002010, Error',
#  'B03002011',
#  'B03002011, Error',
#  'B03002012',
#  'B03002012, Error',
#  'B03002013',
#  'B03002013, Error',
#  'B03002014',
#  'B03002014, Error',
#  'B03002015',
#  'B03002015, Error',
#  'B03002016',
#  'B03002016, Error',
#  'B03002017',
#  'B03002017, Error',
#  'B03002018',
#  'B03002018, Error',
#  'B03002019',
#  'B03002019, Error',
#  'B03002020',
#  'B03002020, Error',
#  'B03002021',
#  'B03002021, Error',
#  'geometry']

# %%
# columns to keep
columns_to_keep = ['geoid',
 'name',
 'B03002001',
 'B03002002',
 'B03002003',
 'B03002004',
 'B03002005',
 'B03002006',
 'B03002007',
 'B03002008',
 'B03002009',
 'B03002012',
 'geometry']

# %%
# redefine gdf with only columns to keep
gdf = gdf[columns_to_keep]

# %%
# check the slimmed down gdf
gdf.head()
# Out:
#                 geoid                             name  B03002001  B03002002  \
# 0  14000US06111002500     Census Tract 25, Ventura, CA     5374.0     4419.0
# 1  14000US06111002901  Census Tract 29.01, Ventura, CA     5665.0     2747.0
# 2  14000US06111002905  Census Tract 29.05, Ventura, CA     5433.0     2339.0
# 3  14000US06111003010  Census Tract 30.10, Ventura, CA     3226.0      805.0
# 4  14000US06111003011  Census Tract 30.11, Ventura, CA     5539.0     1004.0
#
#    B03002003  B03002004  B03002005  B03002006  B03002007  B03002008  \
# 0     4014.0       44.0       97.0      142.0        0.0        0.0
# 1     1538.0      196.0        0.0      679.0        9.0        0.0
# 2     1110.0      450.0        0.0      587.0        0.0       10.0
# 3      445.0       82.0        1.0      255.0        4.0        0.0
# 4      612.0       65.0        0.0      260.0        9.0        0.0
#
#    B03002009  B03002012                                           geometry
# ...

# %%
#list column names
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B03002001',
#  'B03002002',
#  'B03002003',
#  'B03002004',
#  'B03002005',
#  'B03002006',
#  'B03002007',
#  'B03002008',
#  'B03002009',
#  'B03002012',
#  'geometry']

# %%
#rename column headers with race
gdf.columns = ['geoid',
 'name',
 'Total',
 'Non Hispanic',
 'Non Hispanic White',
 'Non Hispanic Black',
 'Non Hispanic American Indian and Alaska Native',
 'Non Hispanic Asian',
 'Non Hispanic Native Hawaiian and Other Pacific Islander',
 'Non Hispanic Some other race',
 'Non Hispanic Two or more races',
 'Hispanic',
 'geometry']

# %%
gdf.head()
# Out:
#                 geoid                             name   Total  Non Hispanic  \
# 0  14000US06111002500     Census Tract 25, Ventura, CA  5374.0        4419.0
# 1  14000US06111002901  Census Tract 29.01, Ventura, CA  5665.0        2747.0
# 2  14000US06111002905  Census Tract 29.05, Ventura, CA  5433.0        2339.0
# 3  14000US06111003010  Census Tract 30.10, Ventura, CA  3226.0         805.0
# 4  14000US06111003011  Census Tract 30.11, Ventura, CA  5539.0        1004.0
#
#    Non Hispanic White  Non Hispanic Black  \
# 0              4014.0                44.0
# 1              1538.0               196.0
# 2              1110.0               450.0
# 3               445.0                82.0
# 4               612.0                65.0
#
#    Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 0                                            97.0               142.0
# 1                                             0.0               679.0
# ...

# %%
# get a random record
random_tract = gdf.sample()
random_tract
# Out:
#                  geoid                             name   Total  Non Hispanic  \
# 22  14000US06111004504  Census Tract 45.04, Ventura, CA  5777.0         910.0
#
#     Non Hispanic White  Non Hispanic Black  \
# 22               207.0               119.0
#
#     Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 22                                            12.0               539.0
#
#     Non Hispanic Native Hawaiian and Other Pacific Islander  \
# 22                                                0.0
#
#     Non Hispanic Some other race  Non Hispanic Two or more races  Hispanic  \
# 22                           0.0                            33.0    4867.0
#
#                                              geometry
# 22  MULTIPOLYGON (((-119.17777 34.15551, -119.1777...

# %%
# hispanic plus all the non hispanice categories
print(random_tract.iloc[0]['Non Hispanic White'] + 
      random_tract.iloc[0]['Non Hispanic Black'] + 
      random_tract.iloc[0]['Non Hispanic American Indian and Alaska Native'] + 
      random_tract.iloc[0]['Non Hispanic Asian'] + 
      random_tract.iloc[0]['Non Hispanic Native Hawaiian and Other Pacific Islander'] + 
      random_tract.iloc[0]['Non Hispanic Some other race'] + 
      random_tract.iloc[0]['Non Hispanic Two or more races'] + 
      random_tract.iloc[0]['Hispanic'])
#data is in order!
# Out:
# 5777.0

# %%
# access a single column 
gdf['Non Hispanic Black'].head()
# Out:
# 0     44.0
# 1    196.0
# 2    450.0
# 3     82.0
# 4     65.0
# Name: Non Hispanic Black, dtype: float64

# %%
#find mean
gdf['Non Hispanic Black'].mean()
# Out:
# 136.06976744186048

# %%
#find median
gdf['Non Hispanic Black'].median()
# Out:
# 100.0

# %%
#get stats on blac pop.
gdf['Non Hispanic Black'].describe()
# Out:
# count     43.000000
# mean     136.069767
# std      131.133228
# min        0.000000
# 25%       36.000000
# 50%      100.000000
# 75%      191.500000
# max      450.000000
# Name: Non Hispanic Black, dtype: float64

# %%
# plot as a historgram in 10 bins
gdf['Non Hispanic Black'].plot.hist(bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# the chart shows the frequency of census tracts with a number of non-hispanic black residents

# %%
#sort census tracts with highest black pop. from highest to lowest but cut to top 10 rows
gdf_sorted = gdf.sort_values(by='Non Hispanic Black',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
gdf_sorted[['geoid','Non Hispanic Black']].head(10)
# Out:
#                  geoid  Non Hispanic Black
# 2   14000US06111002905               450.0
# 10  14000US06111003605               445.0
# 20  14000US06111004304               433.0
# 14  14000US06111003700               410.0
# 32  14000US06111004901               385.0
# 7   14000US06111003100               319.0
# 36  14000US06111005004               285.0
# 6   14000US06111003013               230.0
# 19  14000US06111004101               216.0
# 17  14000US06111003900               216.0

# %%
# plot it
gdf_sorted.head(10).plot()
# Out:
# <AxesSubplot:>

# %%
# Make it prettier
gdf_sorted.head(100).plot(figsize=(10,20),
                          column='Non Hispanic Black',legend=True)
# Out:
# <AxesSubplot:>

# %%
#show census tracts with zero black residents
gdf[gdf['Non Hispanic Black']==0]
# Out:
#                  geoid                             name   Total  Non Hispanic  \
# 5   14000US06111003012  Census Tract 30.12, Ventura, CA   675.0          13.0
# 12  14000US06111003609  Census Tract 36.09, Ventura, CA  5863.0        5347.0
# 33  14000US06111004902  Census Tract 49.02, Ventura, CA  5072.0         106.0
# 42  14000US06111990100   Census Tract 9901, Ventura, CA     0.0           0.0
#
#     Non Hispanic White  Non Hispanic Black  \
# 5                 13.0                 0.0
# 12              5112.0                 0.0
# 33                94.0                 0.0
# 42                 0.0                 0.0
#
#     Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 5                                              0.0                 0.0
# 12                                             0.0               116.0
# 33                                             0.0                12.0
# ...

# %%
# create a new variable for census tracts with zero black pop
gdf_no_blackpop = gdf[gdf['Non Hispanic Black']==0]

# %%
# how many records?
print('There are ' + str(len(gdf_no_blackpop)) + ' census tracts with no non-hispanic black people in them')
# Out:
# There are 4 census tracts with no non-hispanic black people in them

# %%
# display census tracr data
gdf_no_blackpop[['geoid','Non Hispanic Black']]
# Out:
#                  geoid  Non Hispanic Black
# 5   14000US06111003012                 0.0
# 12  14000US06111003609                 0.0
# 33  14000US06111004902                 0.0
# 42  14000US06111990100                 0.0

# %%
# output columns
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'Total',
#  'Non Hispanic',
#  'Non Hispanic White',
#  'Non Hispanic Black',
#  'Non Hispanic American Indian and Alaska Native',
#  'Non Hispanic Asian',
#  'Non Hispanic Native Hawaiian and Other Pacific Islander',
#  'Non Hispanic Some other race',
#  'Non Hispanic Two or more races',
#  'Hispanic',
#  'geometry']

# %%
# create a new column, and populate it with normalized data to get the percent of total value
gdf['Percent Non Hispanic White'] = gdf['Non Hispanic White']/gdf['Total']*100
#combine row values for non-whites and put in new column
gdf['Hispanic + Non-Hispanic Non-White'] = gdf['Non Hispanic Black'] + gdf['Non Hispanic American Indian and Alaska Native'] + gdf['Non Hispanic Asian'] + gdf['Non Hispanic Native Hawaiian and Other Pacific Islander'] + gdf['Non Hispanic Some other race'] + gdf['Non Hispanic Two or more races'] + gdf['Hispanic']
gdf['Percent Hispanic + Non-Hispanic Non-White'] = gdf['Hispanic + Non-Hispanic Non-White']/gdf['Total']*100

# %%
gdf.sample(5)
# Out:
#                  geoid                             name   Total  Non Hispanic  \
# 34  14000US06111005002  Census Tract 50.02, Ventura, CA  3339.0         209.0
# 17  14000US06111003900     Census Tract 39, Ventura, CA  6984.0         872.0
# 22  14000US06111004504  Census Tract 45.04, Ventura, CA  5777.0         910.0
# 33  14000US06111004902  Census Tract 49.02, Ventura, CA  5072.0         106.0
# 36  14000US06111005004  Census Tract 50.04, Ventura, CA  9833.0        4698.0
#
#     Non Hispanic White  Non Hispanic Black  \
# 34               187.0                21.0
# 17               241.0               216.0
# 22               207.0               119.0
# 33                94.0                 0.0
# 36              2716.0               285.0
#
#     Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 34                                             0.0                 0.0
# 17                                             0.0               387.0
# ...

# %%
#add percent columns for each race
gdf['Percent Non Hispanic White'] = gdf['Non Hispanic White']/gdf['Total']*100
gdf['Percent Non Hispanic Black'] = gdf['Non Hispanic Black']/gdf['Total']*100
gdf['Percent Non Hispanic American Indian and Alaska Native'] = gdf['Non Hispanic American Indian and Alaska Native']/gdf['Total']*100
gdf['Percent Non Hispanic Asian'] = gdf['Non Hispanic Asian']/gdf['Total']*100
gdf['Percent Non Hispanic Native Hawaiian and Other Pacific Islander'] = gdf['Non Hispanic Native Hawaiian and Other Pacific Islander']/gdf['Total']*100
gdf['Percent Non Hispanic Some other race'] = gdf['Non Hispanic Some other race']/gdf['Total']*100
gdf['Percent Non Hispanic Two or more races'] = gdf['Non Hispanic Two or more races']/gdf['Total']*100

# %%
#show data with new columns
gdf.head()
# Out:
#                 geoid                             name   Total  Non Hispanic  \
# 0  14000US06111002500     Census Tract 25, Ventura, CA  5374.0        4419.0
# 1  14000US06111002901  Census Tract 29.01, Ventura, CA  5665.0        2747.0
# 2  14000US06111002905  Census Tract 29.05, Ventura, CA  5433.0        2339.0
# 3  14000US06111003010  Census Tract 30.10, Ventura, CA  3226.0         805.0
# 4  14000US06111003011  Census Tract 30.11, Ventura, CA  5539.0        1004.0
#
#    Non Hispanic White  Non Hispanic Black  \
# 0              4014.0                44.0
# 1              1538.0               196.0
# 2              1110.0               450.0
# 3               445.0                82.0
# 4               612.0                65.0
#
#    Non Hispanic American Indian and Alaska Native  Non Hispanic Asian  \
# 0                                            97.0               142.0
# 1                                             0.0               679.0
# ...

# %%
gdf.plot(figsize=(12,10),
                 column='Percent Non Hispanic White',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot:>

# %%
gdf.plot(figsize=(12,20),
                 column='Percent Non Hispanic White',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot:>

# %%
gdf.plot(figsize=(12,30),
                 column='Percent Non Hispanic White',
                 legend=True, 
                 scheme='quantiles')
# Out:
# <AxesSubplot:>

# %%
# create the 1x2 subplots
fig, axs = plt.subplots(1, 2, figsize=(30, 10))

# name each subplot
ax1, ax2 = axs

# percent hispanic map on the left
gdf.plot(column='Percent Non Hispanic White', 
            cmap='OrRd', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("Percent Non Hispanic White")

# percent black map on the right
gdf.plot(column='Percent Hispanic + Non-Hispanic Non-White', 
            cmap='OrRd', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot
            legend=True
           )

ax2.axis("off")
ax2.set_title("Percent Hispanic + Non-Hispanic Non-White")
# Out:
# Text(0.5, 1.0, 'Percent Hispanic + Non-Hispanic Non-White')

# %%
#arrange dataset to sort 90% of pop is non-white residents fro most to least
gdf[gdf['Percent Hispanic + Non-Hispanic Non-White'] > 90]
# Out:
#                  geoid                             name   Total  Non Hispanic  \
# 5   14000US06111003012  Census Tract 30.12, Ventura, CA   675.0          13.0
# 8   14000US06111003201  Census Tract 32.01, Ventura, CA  4230.0         103.0
# 14  14000US06111003700     Census Tract 37, Ventura, CA  6687.0         724.0
# 15  14000US06111003801  Census Tract 38.01, Ventura, CA  5033.0         348.0
# 16  14000US06111003802  Census Tract 38.02, Ventura, CA  2849.0         258.0
# 17  14000US06111003900     Census Tract 39, Ventura, CA  6984.0         872.0
# 18  14000US06111004000     Census Tract 40, Ventura, CA  7179.0         816.0
# 19  14000US06111004101  Census Tract 41.01, Ventura, CA  6947.0        1041.0
# 22  14000US06111004504  Census Tract 45.04, Ventura, CA  5777.0         910.0
# 23  14000US06111004505  Census Tract 45.05, Ventura, CA  2208.0         206.0
# 24  14000US06111004506  Census Tract 45.06, Ventura, CA  7788.0         605.0
# ...

# %%
# create map of where over 90% of pop is non-white live
gdf[gdf['Percent Hispanic + Non-Hispanic Non-White'] > 90].plot(figsize=(12,20))
# Out:
# <AxesSubplot:>

# %%
# reproject to Web Mercator
gdf_web_mercator = gdf.to_crs(epsg=3857)

# %%
# use subplots that make it easier to create multiple layered maps
fig, ax = plt.subplots(figsize=(10, 10))

# add the layer with ax=ax in the argument 
gdf_web_mercator[gdf_web_mercator['Percent Non Hispanic White'] > 80].plot(ax=ax, alpha=0.45)

# turn the axis off
ax.axis('off')

# set a title
ax.set_title('Census Tracts with More than 90% White Population',fontsize=16)

# add a basemap
ctx.add_basemap(ax)

# %%
#Lupe V. completed a race population analysis on Malibu, CA, like I have down with Oxanrd, CA above
